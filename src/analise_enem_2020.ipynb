# %% [markdown]
# # Análise de Dados - ENEM 2020
# Visualização e análise dos dados tratados.

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

PROCESSED_PATH = r'..\data\processed\enem_2020_tratado.parquet'

# %% [markdown]
# ## 1. Carregamento dos dados tratados

# %%
df = pd.read_parquet(PROCESSED_PATH)
print(f'Shape: {df.shape}')
df.head()
# Out:
# Shape: (5783109, 76)
#   Numero_Inscricao   Ano  Faixa_Etaria Sexo  Estado_Civil  Cor_Raca  \
# 0     200006271946  2020            11    F             1         2
# 1     200001195856  2020            11    M             2         3
# 2     200001943954  2020             4    F             2         3
# 3     200001908998  2020             2    M             1         3
# 4     200001634757  2020             4    F             1         3
#
#    Nacionalidade  Situacao_Conclusao_EM  Ano_Conclusao_EM  Tipo_Escola  ...  \
# 0              1                      1                11            1  ...
# 1              1                      1                11            1  ...
# 2              2                      2                 0            2  ...
# 3              1                      2                 0            2  ...
# 4              2                      1                 1            1  ...
#
#    Q16_Micro_Ondas  Q17_Maquina_Lavar_Louca  Q18_Aspirador_Po Q19_TV_Cores  \
# 0              NaN                      NaN               NaN          NaN
# 1              NaN                      NaN               NaN          NaN
# 2                B                        A                 A            B
# 3              NaN                      NaN               NaN          NaN
# 4                A                        A                 A            B
#
#    Q20_DVD Q21_TV_Assinatura  Q22_Telefone_Fixo  Q23_Computador  Q24_Internet  \
# 0      NaN               NaN                NaN             NaN           NaN
# 1      NaN               NaN                NaN             NaN           NaN
# 2        A                 A                  A               A             A
# 3      NaN               NaN                NaN             NaN           NaN
# 4        A                 B                  B               A             A
#
#    Q25_Celular
# 0          NaN
# 1          NaN
# 2            A
# 3          NaN
# 4            B
#
# [5 rows x 76 columns]
